# %%
import pandas as pd
import numpy as np

# %%
lyrics_file = 'data/billboard_lyrics_1964-2015.csv'

# %%
lyrics_data = pd.read_csv(lyrics_file)

# %%
lyrics_data["WordCount"] = ""

# %%
lyrics_data.head()

# %%
artist_group = lyrics_data.groupby('Artist')

# %%
artist_count = artist_group["Artist"].count()

# %%
artist_count.sort_values(ascending = False).head(50)

# %%
lyrics_data.Lyrics = lyrics_data.Lyrics.astype('str') 
for i in lyrics_data.index:
    print(lyrics_data['Song'][i], len(lyrics_data['Lyrics'][i].split()))
# Out:
# wooly bully 125
# i cant help myself sugar pie honey bunch 204
# i cant get no satisfaction 0
# you were on my mind 152
# youve lost that lovin feelin 232
# downtown 239
# help 228
# cant you hear my heart beat 215
# crying in the chapel 148
# my girl 153
# help me rhonda 299
# king of the road 169
# the birds and the bees 204
# hold me thrill me kiss me 241
# shotgun 134
# i got you babe 222
# this diamond ring 170
# the in crowd 1
# mrs brown youve got a lovely daughter 198
# stop in the name of love 233
# unchained melody 176
# silhouettes 155
# ill never find another you 166
# cara mia 148
# mr tambourine man 138
# cast your fate to the wind 85
# yes im ready 184
# whats new pussycat 137
# eve of destruction 291
# hang on sloopy 154
# ticket to ride 273
# red roses for a blue lady 139
# papas got a brand new bag 113
# game of love 260
# the name game 287
# i know a place 280
# back in my arms again 235
# baby im yours 144
# the jolly green giant 217
# ...
