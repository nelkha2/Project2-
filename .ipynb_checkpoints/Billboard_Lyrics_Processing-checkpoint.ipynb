# %%
import pandas as pd
import numpy as np
import lyricsgenius
from config import u, p
from sqlalchemy import create_engine

# %%
database_path = f'postgresql://{u}:{p}@localhost:5432/billboard_db'

# %%
genius = lyricsgenius.Genius("p6ctaU5y06hG-yggcUBTOqTlDIiZBSKzarJVoy6rn5w9R2fYkgHhRZAzbChbmSCh")
genius.verbose = True # Turn on/off status messages
genius.remove_section_headers = True # Remove section headers (e.g. [Chorus]) from lyrics when searching
genius.skip_non_songs = False # Include hits thought to be non-songs (e.g. track lists)
genius.excluded_terms = ["(Remix)", "(Live)"] # Exclude songs with these words in their title

# %%
lyrics_file = 'data/billboard_lyrics_1964-2015.csv'
songs_file = 'data/billboard_hot_100_1965_to_2018.csv'

# %%
lyrics_data = pd.read_csv(lyrics_file)
songs_data = pd.read_csv(songs_file).set_index("RankId")

# %%
songs_data.head()
# Out:
#         Rank                                         Song  \
# RankId
# 1          1                                  Wooly Bully
# 2          2  I Can't Help Myself (Sugar Pie Honey Bunch)
# 3          3                (I Can't Get No) Satisfaction
# 4          4                          You Were on My Mind
# 5          5              You've Lost That Lovin' Feelin'
#
#                                Artist  Year
# RankId
# 1       Sam the Sham and the Pharaohs  1965
# 2                           Four Tops  1965
# 3                  The Rolling Stones  1965
# 4                             We Five  1965
# 5              The Righteous Brothers  1965

# %%
lyrics_data.head()
# Out:
#    Rank                                      Song  \
# 0     1                               wooly bully
# 1     2  i cant help myself sugar pie honey bunch
# 2     3                i cant get no satisfaction
# 3     4                       you were on my mind
# 4     5              youve lost that lovin feelin
#
#                           Artist  Year  \
# 0  sam the sham and the pharaohs  1965
# 1                      four tops  1965
# 2             the rolling stones  1965
# 3                        we five  1965
# 4         the righteous brothers  1965
#
#                                               Lyrics  Source
# 0  sam the sham miscellaneous wooly bully wooly b...     3.0
# 1   sugar pie honey bunch you know that i love yo...     1.0
# 2                                                        1.0
# 3   when i woke up this morning you were on my mi...     1.0
# 4   you never close your eyes anymore when i kiss...     1.0

# %%
#merge the file
song_merged = pd.merge(songs_data, lyrics_data,  how='left', left_on = ['Rank','Year'], right_on = ['Rank','Year'])

# %%
song_merged.head()
# Out:
#    Rank                                       Song_x  \
# 0     1                                  Wooly Bully
# 1     2  I Can't Help Myself (Sugar Pie Honey Bunch)
# 2     3                (I Can't Get No) Satisfaction
# 3     4                          You Were on My Mind
# 4     5              You've Lost That Lovin' Feelin'
#
#                         Artist_x  Year  \
# 0  Sam the Sham and the Pharaohs  1965
# 1                      Four Tops  1965
# 2             The Rolling Stones  1965
# 3                        We Five  1965
# 4         The Righteous Brothers  1965
#
#                                      Song_y                       Artist_y  \
# 0                               wooly bully  sam the sham and the pharaohs
# 1  i cant help myself sugar pie honey bunch                      four tops
# 2                i cant get no satisfaction             the rolling stones
# 3                       you were on my mind                        we five
# ...

# %%
#add colummn for genius lyrics
song_merged["GeniusLyrics"] = ""

#get lyrics
for i in song_merged.index[0:20]:
    artist = song_merged['Artist_x'][i]
    song = song_merged['Song_x'][i]
    if song_merged['GeniusLyrics'][i] == "":
        try:
            genius_lyrics = genius.search_song(song, artist)
            song_merged.at[i,'GeniusLyrics'] = genius_lyrics.lyrics
        except(AttributeError):
            print(f"{song} not found. Skipping...\n")
# Out:
# Searching for "Wooly Bully" by Sam the Sham and the Pharaohs...
# Done.
# Searching for "I Can't Help Myself (Sugar Pie Honey Bunch)" by Four Tops...
# Done.
# Searching for "(I Can't Get No) Satisfaction" by The Rolling Stones...
# Done.
# Searching for "You Were on My Mind" by We Five...
# Done.
# Searching for "You've Lost That Lovin' Feelin'" by The Righteous Brothers...
# Done.
# Searching for "Downtown" by Petula Clark...
# Done.
# Searching for "Help!" by The Beatles...
# Done.
# Searching for "Can't You Hear My Heartbeat" by Herman's Hermits...
# Done.
# Searching for "Crying in the Chapel" by Elvis Presley...
# Done.
# Searching for "My Girl" by The Temptations...
# Done.
# Searching for "Help Me, Rhonda" by The Beach Boys...
# Done.
# Searching for "King of the Road" by Roger Miller...
# Done.
# Searching for "The Birds and the Bees" by Jewel Akens...
# Done.
# Searching for "Hold Me, Thrill Me, Kiss Me" by Mel Carter...
# Done.
# ...

# %%
song_merged.head(20)
# Out:
#     Rank                                       Song_x  \
# 0      1                                  Wooly Bully
# 1      2  I Can't Help Myself (Sugar Pie Honey Bunch)
# 2      3                (I Can't Get No) Satisfaction
# 3      4                          You Were on My Mind
# 4      5              You've Lost That Lovin' Feelin'
# 5      6                                     Downtown
# 6      7                                        Help!
# 7      8                  Can't You Hear My Heartbeat
# 8      9                         Crying in the Chapel
# 9     10                                      My Girl
# 10    11                              Help Me, Rhonda
# 11    12                             King of the Road
# 12    13                       The Birds and the Bees
# 13    14                  Hold Me, Thrill Me, Kiss Me
# 14    15                                      Shotgun
# 15    16                               I Got You Babe
# ...

# %%
#export to excel for review
song_merged.to_csv('data/billboard_hot_100_1965_to_2018_with_lyrics.csv')

# %%
#view the formatted lyrics
for i in songs_data.index[7:8]:
    print(songs_data['Lyrics'][i])

# %%
##### Artist Counts ######

# %%
#group records by artist
artist_group = songs_data.groupby('Artist')

#get group by count
artist_count = artist_group["Artist"].count()

# %%
artist_count.sort_values(ascending = False).head()

# %%
#get word count for each song
song_merged["WordCount"] = ""
song_merged.Lyrics = song_merged.Lyrics.astype('str') 
for i in song_merged.index:
    print(song_merged['Song'][i], len(song_merged['Lyrics'][i].split()))
